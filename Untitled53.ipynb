# %% [markdown]
# <a href="https://colab.research.google.com/github/BosenkoTM/RepoData/blob/main/Untitled53.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
number = int(input())
is_even = (number % 2 == 0)
print(is_even)
# Out:
# 7
# False

# %%
# Задание task_01_01.
""" Составьте программу, которая запрашивает у пользователя 2 целых числа и выполняет операции:
•	арифметические: +, -, * , / , // , %, **;
•	сравнение: <, <=, >, >=, !=, ==,
выводя на экран результат каждого действия. В случае получение вещественного результата, округлите его до 2-х знаков после запятой (используя функцию round()).
"""
# Выполнил: Фамилия И.О.
# Группа: !!!


a = int(input("a="))
b = int(input("b=")) # Удалите комментарий и допишите код

print(a + b)
print(a - b)
print(a * b)
print(round(a / b, 2))
print(a // b)
print(a < b)



# --------------
# Пример вывода:
#
# a=2
# b=3
# 5
# -1
# 6
# 0.67
# 0
# 2
# 8
# True
# True
# False
# False
# True
# False
# Out:
# a=2
# b=3
# 5
# -1
# 6
# 0.67
# True
